# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import IntegerType, BooleanType
from pyspark.sql.window import Window
import re

# %%
# 创建 SparkSession
spark = SparkSession\
    .builder\
    .appName("batch_processing")\
    .master("local[*]")\
    .getOrCreate()

# %% [markdown]
# ### 读取文件

# %%
base_path = "F:/大四/大数据/tennis_slam_pointbypoint/"
df = spark.read.option("header", "true").option("inferSchema", "true").csv(f"{base_path}*-points.csv")

# %%
df.columns
# Out:
# ['match_id',
#  'ElapsedTime',
#  'SetNo',
#  'P1GamesWon',
#  'P2GamesWon',
#  'SetWinner',
#  'GameNo',
#  'GameWinner',
#  'PointNumber',
#  'PointWinner',
#  'PointServer',
#  'Speed_KMH',
#  'Rally',
#  'P1Score',
#  'P2Score',
#  'P1Momentum',
#  'P2Momentum',
#  'P1PointsWon',
#  'P2PointsWon',
#  'P1Ace',
#  'P2Ace',
#  'P1Winner',
#  'P2Winner',
#  'P1DoubleFault',
#  'P2DoubleFault',
#  'P1UnfErr',
#  'P2UnfErr',
#  'P1NetPoint',
#  'P2NetPoint',
#  'P1NetPointWon',
#  'P2NetPointWon',
#  'P1BreakPoint',
#  'P2BreakPoint',
#  'P1BreakPointWon',
#  'P2BreakPointWon',
#  'P1FirstSrvIn',
#  'P2FirstSrvIn',
#  'P1FirstSrvWon',
#  'P2FirstSrvWon',
#  'P1SecondSrvIn',
#  'P2SecondSrvIn',
#  'P1SecondSrvWon',
#  'P2SecondSrvWon',
#  'P1ForcedError',
#  'P2ForcedError',
#  'History',
#  'Speed_MPH',
#  'P1BreakPointMissed',
#  'P2BreakPointMissed',
#  'ServeIndicator',
#  'Serve_Direction',
#  'Winner_FH',
#  'Winner_BH',
#  'ServingTo',
#  'P1TurningPoint',
#  'P2TurningPoint',
#  'ServeNumber',
#  'WinnerType',
#  'WinnerShotType',
#  'P1DistanceRun',
#  'P2DistanceRun',
#  'RallyCount',
#  'ServeWidth',
#  'ServeDepth',
#  'ReturnDepth']

# %% [markdown]
# ### 筛选列 清理缺失值

# %%
columns = [
    "match_id", "SetNo", "P1GamesWon", "P2GamesWon", "SetWinner", "GameNo","GameWinner",
    "PointNumber", "PointWinner", "PointServer", "Speed_KMH", "P1PointsWon", "P2PointsWon", "P1Ace", "P2Ace", "P1Winner",
    "P2Winner", "P1DoubleFault", "P2DoubleFault", "P1UnfErr", "P2UnfErr",
    "P1NetPoint", "P2NetPoint", "P1NetPointWon", "P2NetPointWon", "P1BreakPoint",
    "P2BreakPoint", "P1BreakPointWon", "P2BreakPointWon", "Speed_MPH", "ServeIndicator","WinnerType", "WinnerShotType", 
]
selected_df = df.select(columns)
selected_df.show(n=1,vertical=True)
# Out:
# -RECORD 0------------------------------
#  match_id        | 2023-wimbledon-1101
#  SetNo           | 1
#  P1GamesWon      | 0
#  P2GamesWon      | 0
#  SetWinner       | 0
#  GameNo          | 1
#  GameWinner      | 0
#  PointNumber     | 0X
#  PointWinner     | 0
#  PointServer     | 0
#  Speed_KMH       | 0
#  P1PointsWon     | 0
#  P2PointsWon     | 0
#  P1Ace           | 0
#  P2Ace           | 0
#  P1Winner        | 0
#  P2Winner        | 0
#  P1DoubleFault   | 0
#  P2DoubleFault   | 0
#  P1UnfErr        | 0
#  P2UnfErr        | 0
#  P1NetPoint      | 0
#  P2NetPoint      | 0
#  P1NetPointWon   | 0
#  P2NetPointWon   | 0
#  P1BreakPoint    | 0
#  P2BreakPoint    | 0
#  P1BreakPointWon | 0
#  P2BreakPointWon | 0
#  Speed_MPH       | 0
#  ServeIndicator  | 0
#  WinnerType      | 0
#  WinnerShotType  | 0
# only showing top 1 row

# %% [markdown]
# ### 数据清洗

# %%
for column in columns:
    unique_values_df = selected_df.select(column).distinct()
    print(f"Unique values for column '{column}':")
    unique_values_df.show(truncate=False)
# Out:
# Unique values for column 'match_id':
# +-------------------+
# |match_id           |
# +-------------------+
# |2023-wimbledon-1147|
# |2023-wimbledon-1227|
# |2023-wimbledon-2108|
# |2023-wimbledon-1150|
# |2023-wimbledon-2220|
# |2024-wimbledon-2112|
# |2024-wimbledon-2502|
# |2024-wimbledon-1158|
# |2024-wimbledon-2110|
# |2024-wimbledon-2124|
# |2024-wimbledon-2212|
# |2024-wimbledon-2501|
# |2023-wimbledon-1125|
# |2023-wimbledon-2138|
# |2024-wimbledon-1134|
# |2023-wimbledon-2225|
# |2023-wimbledon-2406|
# |2024-wimbledon-1139|
# |2024-wimbledon-2228|
# |2023-wimbledon-1111|
# +-------------------+
# only showing top 20 rows
#
# Unique values for column 'SetNo':
# +-----+
# |SetNo|
# +-----+
# |3    |
# |5    |
# |1    |
# |4    |
# |2    |
# |NULL |
# +-----+
#
# Unique values for column 'P1GamesWon':
# +----------+
# |P1GamesWon|
# +----------+
# |7         |
# |3         |
# |0         |
# |5         |
# |6         |
# |1         |
# |4         |
# |2         |
# |11        |
# |8         |
# |9         |
# |10        |
# |12        |
# |13        |
# |15        |
# |22        |
# |16        |
# |18        |
# |17        |
# |26        |
# +----------+
# only showing top 20 rows
#
# Unique values for column 'P2GamesWon':
# +----------+
# |P2GamesWon|
# +----------+
# |7         |
# |3         |
# |0         |
# |5         |
# |6         |
# |1         |
# |4         |
# |2         |
# |11        |
# |8         |
# |9         |
# |10        |
# |12        |
# |15        |
# |22        |
# |16        |
# |18        |
# |17        |
# |19        |
# |23        |
# +----------+
# only showing top 20 rows
#
# Unique values for column 'SetWinner':
# +---------+
# |SetWinner|
# +---------+
# |0        |
# |1        |
# |2        |
# |NULL     |
# +---------+
#
# Unique values for column 'GameNo':
# +------+
# |GameNo|
# +------+
# |7     |
# |11    |
# |3     |
# |8     |
# |5     |
# |6     |
# |9     |
# |1     |
# |10    |
# |4     |
# |12    |
# |13    |
# |2     |
# |15    |
# |22    |
# |16    |
# |18    |
# |17    |
# |19    |
# |23    |
# +------+
# only showing top 20 rows
#
# Unique values for column 'GameWinner':
# +----------+
# |GameWinner|
# +----------+
# |0         |
# |1         |
# |2         |
# |NULL      |
# +----------+
#
# Unique values for column 'PointNumber':
# +-----------+
# |PointNumber|
# +-----------+
# |296        |
# |125        |
# |7          |
# |51         |
# |124        |
# |307        |
# |169        |
# |205        |
# |334        |
# |272        |
# |15         |
# |54         |
# |232        |
# |234        |
# |282        |
# |155        |
# |132        |
# |154        |
# |317        |
# |200        |
# +-----------+
# only showing top 20 rows
#
# Unique values for column 'PointWinner':
# +-----------+
# |PointWinner|
# +-----------+
# |0          |
# |1          |
# |2          |
# |NULL       |
# +-----------+
#
# Unique values for column 'PointServer':
# +-----------+
# |PointServer|
# +-----------+
# |0          |
# |1          |
# |2          |
# |NULL       |
# +-----------+
#
# Unique values for column 'Speed_KMH':
# +---------+
# |Speed_KMH|
# +---------+
# |125      |
# |154      |
# |101      |
# |138      |
# |112      |
# |133      |
# |162      |
# |146      |
# |160      |
# |199      |
# |183      |
# |0        |
# |188      |
# |98       |
# |223      |
# |99       |
# |107      |
# |214      |
# |202      |
# |206      |
# +---------+
# only showing top 20 rows
#
# Unique values for column 'P1PointsWon':
# +-----------+
# |P1PointsWon|
# +-----------+
# |125        |
# |7          |
# |51         |
# |124        |
# |169        |
# |15         |
# |54         |
# |155        |
# |132        |
# |154        |
# |11         |
# |101        |
# |138        |
# |29         |
# |69         |
# |42         |
# |112        |
# |73         |
# |87         |
# |64         |
# +-----------+
# only showing top 20 rows
#
# Unique values for column 'P2PointsWon':
# +-----------+
# |P2PointsWon|
# +-----------+
# |125        |
# |7          |
# |51         |
# |124        |
# |169        |
# |15         |
# |54         |
# |155        |
# |132        |
# |154        |
# |11         |
# |101        |
# |138        |
# |29         |
# |69         |
# |42         |
# |112        |
# |73         |
# |87         |
# |64         |
# +-----------+
# only showing top 20 rows
#
# Unique values for column 'P1Ace':
# +-----+
# |P1Ace|
# +-----+
# |0    |
# |1    |
# |NULL |
# +-----+
#
# Unique values for column 'P2Ace':
# +-----+
# |P2Ace|
# +-----+
# |0    |
# |1    |
# |NULL |
# +-----+
#
# Unique values for column 'P1Winner':
# +--------+
# |P1Winner|
# +--------+
# |0       |
# |1       |
# |NULL    |
# +--------+
#
# Unique values for column 'P2Winner':
# +--------+
# |P2Winner|
# +--------+
# |0       |
# |1       |
# |NULL    |
# +--------+
#
# Unique values for column 'P1DoubleFault':
# +-------------+
# |P1DoubleFault|
# +-------------+
# |0            |
# |1            |
# |NULL         |
# +-------------+
#
# Unique values for column 'P2DoubleFault':
# +-------------+
# |P2DoubleFault|
# +-------------+
# |0            |
# |1            |
# |NULL         |
# +-------------+
#
# Unique values for column 'P1UnfErr':
# +--------+
# |P1UnfErr|
# +--------+
# |0       |
# |1       |
# |NULL    |
# +--------+
#
# Unique values for column 'P2UnfErr':
# +--------+
# |P2UnfErr|
# +--------+
# |0       |
# |1       |
# |NULL    |
# +--------+
#
# Unique values for column 'P1NetPoint':
# +----------+
# |P1NetPoint|
# +----------+
# |0         |
# |1         |
# |NULL      |
# +----------+
#
# Unique values for column 'P2NetPoint':
# +----------+
# |P2NetPoint|
# +----------+
# |0         |
# |1         |
# |NULL      |
# +----------+
#
# Unique values for column 'P1NetPointWon':
# +-------------+
# |P1NetPointWon|
# +-------------+
# |0            |
# |1            |
# |NULL         |
# +-------------+
#
# Unique values for column 'P2NetPointWon':
# +-------------+
# |P2NetPointWon|
# +-------------+
# |0            |
# |1            |
# |NULL         |
# +-------------+
#
# Unique values for column 'P1BreakPoint':
# +------------+
# |P1BreakPoint|
# +------------+
# |0           |
# |1           |
# |NULL        |
# +------------+
#
# Unique values for column 'P2BreakPoint':
# +------------+
# |P2BreakPoint|
# +------------+
# |0           |
# |1           |
# |NULL        |
# +------------+
#
# Unique values for column 'P1BreakPointWon':
# +---------------+
# |P1BreakPointWon|
# +---------------+
# |0              |
# |1              |
# |NULL           |
# +---------------+
#
# Unique values for column 'P2BreakPointWon':
# +---------------+
# |P2BreakPointWon|
# +---------------+
# |0              |
# |1              |
# |NULL           |
# +---------------+
#
# Unique values for column 'Speed_MPH':
# +---------+
# |Speed_MPH|
# +---------+
# |125      |
# |124      |
# |132      |
# |101      |
# |138      |
# |69       |
# |112      |
# |87       |
# |73       |
# |64       |
# |113      |
# |133      |
# |139      |
# |85       |
# |0        |
# |71       |
# |98       |
# |99       |
# |110      |
# |107      |
# +---------+
# only showing top 20 rows
#
# Unique values for column 'ServeIndicator':
# +--------------+
# |ServeIndicator|
# +--------------+
# |0             |
# |1             |
# |2             |
# |NULL          |
# +--------------+
#
# Unique values for column 'WinnerType':
# +----------+
# |WinnerType|
# +----------+
# |0         |
# |S         |
# |NULL      |
# +----------+
#
# Unique values for column 'WinnerShotType':
# +--------------+
# |WinnerShotType|
# +--------------+
# |F             |
# |0             |
# |B             |
# |NULL          |
# +--------------+

# %%
#异常及含义不清数据查看  %PointsWon== 0 时表示比赛刚开始
#filtered_df.filter((F.col("Speed_MPH")=="0")&(F.col("P1PointsWon")=="0")&(F.col("P2PointsWon")=="0")).show(vertical=True)
#filtered_df.filter((F.col("WinnerType")=="S")&(F.col("P1PointsWon")=="0")&(F.col("P2PointsWon")=="0")).show(vertical=True)
#filtered_df.filter((F.col("WinnerType")=="S")&(F.col("P2Ace")=="1")).show(vertical=True)
#WinnerType == S 时表示发球直得,不含Ace
#filtered_df.filter((F.col("P1UnfErr")=="1")&(F.col("P1DoubleFault")=="1")).show(vertical=True) 非受迫失误包含双误
#filtered_df.filter((F.col("ServeNumber")=="1")).show(vertical=True)  servenumber意义不明
#filtered_df.filter((F.col("P1GamesWon")>7)).show(vertical=True) #count=2778
#filtered_df.filter((F.col("Speed_KMH")!= 0)).count() #非空值807119   空值364202
#selected_df.filter(F.col("Speed_KMH").isNull() & F.col("Speed_MPH").isNotNull()).show(vertical=True) Speed_KMH为null且Speed_MPH不为空的行

# %%
mph_to_kmh = 1.60934
selected_df = selected_df.withColumn(
    "Speed_KMH_Converted",
    F.when(F.col("Speed_KMH").isNull(), F.col("Speed_MPH") * mph_to_kmh).otherwise(F.col("Speed_KMH"))
)
selected_df = selected_df.drop("Speed_MPH")

# %%
filtered_df = selected_df.filter(
    ~(
        (F.col("PointNumber") == "0X") |
        (F.col("PointNumber") == "0Y") |
        (F.col("PointNumber") == "0")  |
        (F.col("PointWinner") == "0")  
    )
)

# %%
filtered_df_with_nulls = filtered_df.filter(
    F.concat(*[F.col(c).isNull().cast("int") for c in filtered_df.columns]).contains(1)
)

# 显示包含 null 值的行
filtered_df_with_nulls.show(vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 1
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 218
#  P1PointsWon         | 1
#  P2PointsWon         | 0
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 218
# -RECORD 1-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 2
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 162
#  P1PointsWon         | 1
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 162
# -RECORD 2-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 3
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 179
#  P1PointsWon         | 1
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 1
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 179
# -RECORD 3-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 4
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 175
#  P1PointsWon         | 2
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 1
#  P2NetPoint          | 1
#  P1NetPointWon       | 1
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 175
# -RECORD 4-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 5
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 180
#  P1PointsWon         | 2
#  P2PointsWon         | 3
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 180
# -RECORD 5-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 2
#  PointNumber         | 6
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 217
#  P1PointsWon         | 2
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 217
# -RECORD 6-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 7
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 197
#  P1PointsWon         | 3
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 197
# -RECORD 7-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 8
#  PointWinner         | 2
#  PointServer         | 1
#  Speed_KMH           | 149
#  P1PointsWon         | 3
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 149
# -RECORD 8-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 9
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 190
#  P1PointsWon         | 4
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 190
# -RECORD 9-----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 10
#  PointWinner         | 2
#  PointServer         | 1
#  Speed_KMH           | 150
#  P1PointsWon         | 4
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 150
# -RECORD 10----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 11
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 178
#  P1PointsWon         | 5
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 178
# -RECORD 11----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 1
#  PointNumber         | 12
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 173
#  P1PointsWon         | 6
#  P2PointsWon         | 6
#  P1Ace               | 1
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 173
# -RECORD 12----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 13
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 173
#  P1PointsWon         | 7
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 173
# -RECORD 13----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 14
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 211
#  P1PointsWon         | 7
#  P2PointsWon         | 7
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 211
# -RECORD 14----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 15
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 181
#  P1PointsWon         | 7
#  P2PointsWon         | 8
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 181
# -RECORD 15----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 16
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 214
#  P1PointsWon         | 7
#  P2PointsWon         | 9
#  P1Ace               | 0
#  P2Ace               | 1
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 214
# -RECORD 16----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 17
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 205
#  P1PointsWon         | 8
#  P2PointsWon         | 9
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 205
# -RECORD 17----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 18
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 163
#  P1PointsWon         | 9
#  P2PointsWon         | 9
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 163
# -RECORD 18----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 1
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 19
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 200
#  P1PointsWon         | 9
#  P2PointsWon         | 10
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 1
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 200
# -RECORD 19----------------------------------
#  match_id            | 2011-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 2
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 2
#  PointNumber         | 20
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 218
#  P1PointsWon         | 9
#  P2PointsWon         | 11
#  P1Ace               | 0
#  P2Ace               | 1
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 218
# only showing top 20 rows

# %%
# 获取 DataFrame 中每一列的 null 值数量
null_counts = filtered_df.select([
    F.sum(F.col(c).isNull().cast("int")).alias(c) for c in filtered_df.columns
])

# 显示含有 null 值的列及其数量
null_counts.show(vertical=True)
# Out:
# -RECORD 0---------------------
#  match_id            | 0
#  SetNo               | 0
#  P1GamesWon          | 369445
#  P2GamesWon          | 369445
#  SetWinner           | 369445
#  GameNo              | 0
#  GameWinner          | 369445
#  PointNumber         | 0
#  PointWinner         | 0
#  PointServer         | 0
#  Speed_KMH           | 91714
#  P1PointsWon         | 369445
#  P2PointsWon         | 369445
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 369445
#  P2NetPoint          | 369445
#  P1NetPointWon       | 369445
#  P2NetPointWon       | 369445
#  P1BreakPoint        | 369445
#  P2BreakPoint        | 369445
#  P1BreakPointWon     | 369445
#  P2BreakPointWon     | 369445
#  ServeIndicator      | 369445
#  WinnerType          | 748523
#  WinnerShotType      | 748523
#  Speed_KMH_Converted | 0

# %%
# 查看指定列含有 null 的行（例如 "SetWinner" 列）
null_in_column_df = filtered_df.filter(F.col("SetWinner").isNull())
null_in_column_df.show(vertical=True, truncate=False)
# Out:
# -RECORD 0-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 1
#  GameWinner          | NULL
#  PointNumber         | 1
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 166
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 166
# -RECORD 1-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 1
#  GameWinner          | NULL
#  PointNumber         | 2
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 130
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 130
# -RECORD 2-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 1
#  GameWinner          | NULL
#  PointNumber         | 3
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 170
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 170
# -RECORD 3-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 1
#  GameWinner          | NULL
#  PointNumber         | 4
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 191
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 191
# -RECORD 4-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 1
#  GameWinner          | NULL
#  PointNumber         | 5
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 198
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 198
# -RECORD 5-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 2
#  GameWinner          | NULL
#  PointNumber         | 6
#  PointWinner         | 2
#  PointServer         | 1
#  Speed_KMH           | 199
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 199
# -RECORD 6-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 2
#  GameWinner          | NULL
#  PointNumber         | 7
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 191
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 191
# -RECORD 7-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 2
#  GameWinner          | NULL
#  PointNumber         | 8
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 181
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 1
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 181
# -RECORD 8-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 2
#  GameWinner          | NULL
#  PointNumber         | 9
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 179
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 179
# -RECORD 9-----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 2
#  GameWinner          | NULL
#  PointNumber         | 10
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 200
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 200
# -RECORD 10----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 3
#  GameWinner          | NULL
#  PointNumber         | 11
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 159
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 159
# -RECORD 11----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 3
#  GameWinner          | NULL
#  PointNumber         | 12
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 151
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 151
# -RECORD 12----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 3
#  GameWinner          | NULL
#  PointNumber         | 13
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 161
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 161
# -RECORD 13----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 3
#  GameWinner          | NULL
#  PointNumber         | 14
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 194
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 194
# -RECORD 14----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 3
#  GameWinner          | NULL
#  PointNumber         | 15
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 149
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 149
# -RECORD 15----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 4
#  GameWinner          | NULL
#  PointNumber         | 16
#  PointWinner         | 2
#  PointServer         | 1
#  Speed_KMH           | 148
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 148
# -RECORD 16----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 4
#  GameWinner          | NULL
#  PointNumber         | 17
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 195
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 1
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 195
# -RECORD 17----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 4
#  GameWinner          | NULL
#  PointNumber         | 18
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 185
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 185
# -RECORD 18----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 4
#  GameWinner          | NULL
#  PointNumber         | 19
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 124
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 124
# -RECORD 19----------------------------------
#  match_id            | 2021-frenchopen-1101
#  SetNo               | 1
#  P1GamesWon          | NULL
#  P2GamesWon          | NULL
#  SetWinner           | NULL
#  GameNo              | 4
#  GameWinner          | NULL
#  PointNumber         | 20
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 200
#  P1PointsWon         | NULL
#  P2PointsWon         | NULL
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | NULL
#  P2NetPoint          | NULL
#  P1NetPointWon       | NULL
#  P2NetPointWon       | NULL
#  P1BreakPoint        | NULL
#  P2BreakPoint        | NULL
#  P1BreakPointWon     | NULL
#  P2BreakPointWon     | NULL
#  ServeIndicator      | NULL
#  WinnerType          | NULL
#  WinnerShotType      | NULL
#  Speed_KMH_Converted | 200
# only showing top 20 rows

# %%
# 计算非零 Speed_KMH 的平均值
#mean_speed = filtered_df.filter(F.col("Speed_KMH") != 0).agg(F.avg("Speed_KMH")).collect()[0][0]
avg_speed_KMH = filtered_df.filter(F.col("Speed_KMH").isNotNull() & (F.col("Speed_KMH") != 0)) \
                           .agg(F.avg("Speed_KMH").alias("avg_Speed_KMH")).collect()[0]["avg_Speed_KMH"]
#对于Speed_MPH 为null和0值时取平均值，对于WinnerType，WinnerShotType空时取0，其他行drop
# 使用平均值替换 Speed_KMH 中的0值
filtered_df = filtered_df.withColumn(
    "Speed_KMH",
    F.when((F.col("Speed_KMH").isNull()) | (F.col("Speed_KMH") == 0), avg_speed_KMH)
     .otherwise(F.col("Speed_KMH"))
)
# 对 WinnerType 和 WinnerShotType 列进行处理
filtered_df = filtered_df.withColumn(
    "WinnerType", 
    F.when(F.col("WinnerType").isNull(), 0)
     .otherwise(F.col("WinnerType"))
)

filtered_df = filtered_df.withColumn(
    "WinnerShotType", 
    F.when(F.col("WinnerShotType").isNull(), 0)
     .otherwise(F.col("WinnerShotType"))
)

filtered_df = filtered_df.dropna(how="any")
# 显示最终的 DataFrame
filtered_df.show(truncate=False,vertical=True)
# Out:
# -RECORD 0----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 1
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 0
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 188
# -RECORD 1----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 2
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 199
#  P1PointsWon         | 1
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | F
#  Speed_KMH_Converted | 199
# -RECORD 2----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 3
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 2
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 0
# -RECORD 3----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 4
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 3
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 0
# -RECORD 4----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 5
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 191
#  P1PointsWon         | 3
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 1
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | F
#  Speed_KMH_Converted | 191
# -RECORD 5----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 1
#  PointNumber         | 6
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 146
#  P1PointsWon         | 4
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 1
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 146
# -RECORD 6----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 7
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 180
#  P1PointsWon         | 5
#  P2PointsWon         | 2
#  P1Ace               | 1
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 180
# -RECORD 7----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 8
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 156
#  P1PointsWon         | 6
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 156
# -RECORD 8----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 9
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 186
#  P1PointsWon         | 7
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 186
# -RECORD 9----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 1
#  PointNumber         | 10
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 152
#  P1PointsWon         | 8
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 152
# -RECORD 10---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 11
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 152
#  P1PointsWon         | 9
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 152
# -RECORD 11---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 12
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 201
#  P1PointsWon         | 9
#  P2PointsWon         | 3
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 201
# -RECORD 12---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 13
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 9
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | F
#  Speed_KMH_Converted | 188
# -RECORD 13---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 14
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 10
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 0
# -RECORD 14---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 15
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 154
#  P1PointsWon         | 10
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 154
# -RECORD 15---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 16
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 11
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 0
# -RECORD 16---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 17
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 11
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 188
# -RECORD 17---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 18
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 199
#  P1PointsWon         | 12
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | F
#  Speed_KMH_Converted | 199
# -RECORD 18---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 19
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 146
#  P1PointsWon         | 13
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 1
#  P2NetPoint          | 0
#  P1NetPointWon       | 1
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  WinnerType          | 0
#  WinnerShotType      | F
#  Speed_KMH_Converted | 146
# -RECORD 19---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 3
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 1
#  PointNumber         | 20
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 167
#  P1PointsWon         | 14
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 1
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  WinnerType          | 0
#  WinnerShotType      | 0
#  Speed_KMH_Converted | 167
# only showing top 20 rows

# %% [markdown]
# <!--# 定义窗口，按照 match_id 和 SetNo 排序
# window_spec = Window.partitionBy("match_id").orderBy("PointNumber").rowsBetween(Window.unboundedPreceding, Window.currentRow)
#
# # 创建 P1SetWon 和 P2SetWon 列，基于 SetWinner 列
# df_with_sets = filtered_df.withColumn(
#     "P1SetWon", F.when(F.col("SetWinner") == 1, 1).otherwise(0)
# ).withColumn(
#     "P2SetWon", F.when(F.col("SetWinner") == 2, 1).otherwise(0)
# )
#
# # 计算 P1SetWonAcc 和 P2SetWonAcc，确保累加从 0 开始
# df_with_sets = df_with_sets.withColumn(
#     "P1SetWonAcc", F.sum("P1SetWon").over(window_spec)
# ).withColumn(
#     "P2SetWonAcc", F.sum("P2SetWon").over(window_spec)
# )
#
# # 添加新列 WP，当 P1SetWonAcc 或 P2SetWonAcc 累加到 3 后，设置 WP 为 0 或 1
# df_with_sets = df_with_sets.withColumn(
#     "WP",
#     F.when(F.col("P1SetWonAcc") >= 3, 1)
#     .when(F.col("P2SetWonAcc") >= 3, 0)
#     .otherwise(None)  # 保持为 None 直到累加到 3
# )
#
# # 使用窗口函数传播 WP 值，使得相同 match_id 下所有行的 WP 值一致
# window_spec_match_id = Window.partitionBy("match_id").orderBy("PointNumber").rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing)
#
# # 使用 coalesce 函数来填充 WP 的空值，确保相同 match_id 下的所有行有统一的 WP 值
# df_with_sets = df_with_sets.withColumn(
#     "WP", F.coalesce(F.last("WP", True).over(window_spec_match_id), F.lit(0))  # 如果 WP 为空，默认设置为 0
# )
#
# # 删除 SetWinner 列
# df_result = df_with_sets.drop("SetWinner")
#
# # 显示结果
# #df_result.filter((F.col("SetNo")==1) & (F.col("WP")==1)).show(vertical=True)
# -->

# %% [markdown]
# #### 基于局数分析

# %%
df = filtered_df.withColumn(
    "P1FWinner", F.when((F.col("WinnerShotType") == "F") & (F.col("PointWinner") == 1), 1).otherwise(0)
).withColumn(
    "P1BWinner", F.when((F.col("WinnerShotType") == "B") & (F.col("PointWinner") == 1), 1).otherwise(0)
).withColumn(
    "P2FWinner", F.when((F.col("WinnerShotType") == "F") & (F.col("PointWinner") == 2), 1).otherwise(0)
).withColumn(
    "P2BWinner", F.when((F.col("WinnerShotType") == "B") & (F.col("PointWinner") == 2), 1).otherwise(0)
).withColumn(
    "P1SerWin", F.when((F.col("WinnerType") == "S") & (F.col("PointWinner") == 1), 1).otherwise(0)
).withColumn(
    "P2SerWIn", F.when((F.col("WinnerType") == "S") & (F.col("PointWinner") == 2), 1).otherwise(0)
).withColumn(
    "P1PtWin", F.when((F.col("WinnerType") == "S") & (F.col("PointWinner") == 1), 1).otherwise(0)
).withColumn(
    "P2PtWIn", F.when((F.col("WinnerType") == "S") & (F.col("PointWinner") == 2), 1).otherwise(0)
)
filtered_df = filtered_df.drop("WinnerShotType","WinnerType")

filtered_df.show(vertical=True)
# Out:
# -RECORD 0----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 1
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 0
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 188
# -RECORD 1----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 2
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 199
#  P1PointsWon         | 1
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 199
# -RECORD 2----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 3
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 2
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 0
# -RECORD 3----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 4
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 3
#  P2PointsWon         | 1
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 0
# -RECORD 4----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 0
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 0
#  PointNumber         | 5
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 191
#  P1PointsWon         | 3
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 1
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 191
# -RECORD 5----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 1
#  GameWinner          | 1
#  PointNumber         | 6
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 146
#  P1PointsWon         | 4
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 1
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  Speed_KMH_Converted | 146
# -RECORD 6----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 7
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 180
#  P1PointsWon         | 5
#  P2PointsWon         | 2
#  P1Ace               | 1
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  Speed_KMH_Converted | 180
# -RECORD 7----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 8
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 156
#  P1PointsWon         | 6
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  Speed_KMH_Converted | 156
# -RECORD 8----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 1
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 0
#  PointNumber         | 9
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 186
#  P1PointsWon         | 7
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  Speed_KMH_Converted | 186
# -RECORD 9----------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 2
#  GameWinner          | 1
#  PointNumber         | 10
#  PointWinner         | 1
#  PointServer         | 1
#  Speed_KMH           | 152
#  P1PointsWon         | 8
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 152
# -RECORD 10---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 11
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 152
#  P1PointsWon         | 9
#  P2PointsWon         | 2
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 152
# -RECORD 11---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 12
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 201
#  P1PointsWon         | 9
#  P2PointsWon         | 3
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 201
# -RECORD 12---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 13
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 9
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 1
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 188
# -RECORD 13---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 14
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 10
#  P2PointsWon         | 4
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 0
# -RECORD 14---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 15
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 154
#  P1PointsWon         | 10
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 154
# -RECORD 15---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 16
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 162.59730345536104
#  P1PointsWon         | 11
#  P2PointsWon         | 5
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 1
#  P1UnfErr            | 0
#  P2UnfErr            | 1
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 0
# -RECORD 16---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 17
#  PointWinner         | 2
#  PointServer         | 2
#  Speed_KMH           | 188
#  P1PointsWon         | 11
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 1
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 188
# -RECORD 17---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 18
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 199
#  P1PointsWon         | 12
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 1
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 199
# -RECORD 18---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 2
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 0
#  PointNumber         | 19
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 146
#  P1PointsWon         | 13
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 1
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 1
#  P2NetPoint          | 0
#  P1NetPointWon       | 1
#  P2NetPointWon       | 0
#  P1BreakPoint        | 0
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 0
#  P2BreakPointWon     | 0
#  ServeIndicator      | 2
#  Speed_KMH_Converted | 146
# -RECORD 19---------------------------------
#  match_id            | 2023-wimbledon-1101
#  SetNo               | 1
#  P1GamesWon          | 3
#  P2GamesWon          | 0
#  SetWinner           | 0
#  GameNo              | 3
#  GameWinner          | 1
#  PointNumber         | 20
#  PointWinner         | 1
#  PointServer         | 2
#  Speed_KMH           | 167
#  P1PointsWon         | 14
#  P2PointsWon         | 6
#  P1Ace               | 0
#  P2Ace               | 0
#  P1Winner            | 0
#  P2Winner            | 0
#  P1DoubleFault       | 0
#  P2DoubleFault       | 0
#  P1UnfErr            | 0
#  P2UnfErr            | 0
#  P1NetPoint          | 0
#  P2NetPoint          | 0
#  P1NetPointWon       | 0
#  P2NetPointWon       | 0
#  P1BreakPoint        | 1
#  P2BreakPoint        | 0
#  P1BreakPointWon     | 1
#  P2BreakPointWon     | 0
#  ServeIndicator      | 1
#  Speed_KMH_Converted | 167
# only showing top 20 rows

# %%
df.columns
# Out:
# ['match_id',
#  'SetNo',
#  'P1GamesWon',
#  'P2GamesWon',
#  'SetWinner',
#  'GameNo',
#  'GameWinner',
#  'PointNumber',
#  'PointWinner',
#  'PointServer',
#  'Speed_KMH',
#  'P1PointsWon',
#  'P2PointsWon',
#  'P1Ace',
#  'P2Ace',
#  'P1Winner',
#  'P2Winner',
#  'P1DoubleFault',
#  'P2DoubleFault',
#  'P1UnfErr',
#  'P2UnfErr',
#  'P1NetPoint',
#  'P2NetPoint',
#  'P1NetPointWon',
#  'P2NetPointWon',
#  'P1BreakPoint',
#  'P2BreakPoint',
#  'P1BreakPointWon',
#  'P2BreakPointWon',
#  'ServeIndicator',
#  'WinnerType',
#  'WinnerShotType',
#  'Speed_KMH_Converted',
#  'P1FWinner',
#  'P1BWinner',
#  'P2FWinner',
#  'P2BWinner',
#  'P1SerWin',
#  'P2SerWIn',
#  'P1PtWin',
#  'P2PtWIn']

# %%
wp = (df.groupBy(
    "match_id", "SetNo"
).agg(
    F.max("SetWinner").alias("SetWinP")))

# %%
joined_df = df.join(wp, on=['match_id', 'SetNo'], how='inner')
final_df = joined_df.filter(F.col("SetWinP") != 0)
joined_df.filter(F.col("SetWinP")==0).count()
# Out:
# 10835

# %%
game_based_df = (final_df.groupBy(
    "match_id", "SetNo", "GameNo"
).agg(
    F.max("SetWinP").alias("SetWinP"),
    F.max("GameWinner").alias("G_Winner"),
    F.max("P1GamesWon").alias("G_P1GmWon"),
    F.max("P2GamesWon").alias("G_P2GmWon"),
    F.max("ServeIndicator").alias("G_Ser"),
    F.sum("P1Ace").alias("G_P1Ace"),
    F.sum("P2Ace").alias("G_P2Ace"),
    F.sum("P1Winner").alias("G_P1Wn"),
    F.sum("P2Winner").alias("G_P2Wn"),
    F.sum("P1DoubleFault").alias("G_P1Df"),
    F.sum("P2DoubleFault").alias("G_P2Df"),
    F.sum("P1UnfErr").alias("G_P1UE"),
    F.sum("P2UnfErr").alias("G_P2UE"),
    F.sum("P1NetPoint").alias("G_P1NP"),
    F.sum("P2NetPoint").alias("G_P2NP"),
    F.sum("P1NetPointWon").alias("G_P1NPW"),
    F.sum("P2NetPointWon").alias("G_P2NPW"),
    F.sum("P1BreakPoint").alias("G_P1BP"),
    F.sum("P2BreakPoint").alias("G_P2BP"),
    F.sum("P1BreakPointWon").alias("G_P1BPWon"),
    F.sum("P2BreakPointWon").alias("G_P2BPWon"),
    F.sum("P1FWinner").alias("G_P1FW"),
    F.sum("P1BWinner").alias("G_P1BW"),
    F.sum("P2FWinner").alias("G_P2FW"),
    F.sum("P2BWinner").alias("G_P2BW"),
    F.sum("P1SerWin").alias("G_P1SerW"),
    F.sum("P2SerWin").alias("G_P2SerW"),
    F.avg("Speed_KMH").alias("G_avg_SerSp"),
    F.count("*").alias("G_totalPoints")
    )
)
#.withColumn("id", F.concat(F.col("match_id"), F.lit("_"), F.col("SetNo"), F.lit("_"), F.col("GameNo")))

# %%
game_based_df.describe().show(vertical=True)
# Out:
# -RECORD 0-----------------------------
#  summary       | count
#  match_id      | 241170
#  SetNo         | 241170
#  GameNo        | 241170
#  SetWinP       | 241170
#  G_Winner      | 241170
#  G_P1GmWon     | 241170
#  G_P2GmWon     | 241170
#  G_Ser         | 241170
#  G_P1Ace       | 241170
#  G_P2Ace       | 241170
#  G_P1Wn        | 241170
#  G_P2Wn        | 241170
#  G_P1Df        | 241170
#  G_P2Df        | 241170
#  G_P1UE        | 241170
#  G_P2UE        | 241170
#  G_P1NP        | 241170
#  G_P2NP        | 241170
#  G_P1NPW       | 241170
#  G_P2NPW       | 241170
#  G_P1BP        | 241170
#  G_P2BP        | 241170
#  G_P1BPWon     | 241170
#  G_P2BPWon     | 241170
#  G_P1FW        | 241170
#  G_P1BW        | 241170
#  G_P2FW        | 241170
#  G_P2BW        | 241170
#  G_P1SerW      | 241170
#  G_P2SerW      | 241170
#  G_avg_SerSp   | 241170
#  G_totalPoints | 241170
# -RECORD 1-----------------------------
#  summary       | mean
#  match_id      | NULL
#  SetNo         | 2.1468797943359457
#  GameNo        | 5.547489322884273
#  SetWinP       | 1.4996019405398682
#  G_Winner      | 1.4987892358087656
#  G_P1GmWon     | 2.77609155367583
#  G_P2GmWon     | 2.770933366504955
#  G_Ser         | 1.999929510303935
#  G_P1Ace       | 0.21976614006717254
#  G_P2Ace       | 0.21382841978687234
#  G_P1Wn        | 1.0289878508935606
#  G_P2Wn        | 1.0246050503794004
#  G_P1Df        | 0.1325911182982958
#  G_P2Df        | 0.13323381846830037
#  G_P1UE        | 1.0415018451714557
#  G_P2UE        | 1.042206742132106
#  G_P1NP        | 0.6095575734958742
#  G_P2NP        | 0.6033793589584111
#  G_P1NPW       | 0.41021685947671765
#  G_P2NPW       | 0.40935025086038895
#  G_P1BP        | 0.29715967989385084
#  G_P2BP        | 0.29665795911597626
#  G_P1BPWon     | 0.12431894514243065
#  G_P2BPWon     | 0.12316623128913215
#  G_P1FW        | 0.3843720197371149
#  G_P1BW        | 0.18965460048928143
#  G_P2FW        | 0.38076875233237967
#  G_P2BW        | 0.18999460961147738
#  G_P1SerW      | 0.03430774972011444
#  G_P2SerW      | 0.033192353941203304
#  G_avg_SerSp   | 163.129665862911
#  G_totalPoints | 6.346631007173364
# -RECORD 2-----------------------------
#  summary       | stddev
#  match_id      | NULL
#  SetNo         | 1.0762820403336906
#  GameNo        | 3.2026552596714732
#  SetWinP       | 0.5000008781647135
#  G_Winner      | 0.5002482972041397
#  G_P1GmWon     | 1.8552999361605915
#  G_P2GmWon     | 1.8563997545230684
#  G_Ser         | 0.008395535690506311
#  G_P1Ace       | 0.5424297951641787
#  G_P2Ace       | 0.5314754591179407
#  G_P1Wn        | 1.1043712232263927
#  G_P2Wn        | 1.1005115999546105
#  G_P1Df        | 0.39912877876368485
#  G_P2Df        | 0.40053811388745997
#  G_P1UE        | 1.148884609501328
#  G_P2UE        | 1.1500601674394602
#  G_P1NP        | 0.9077958761557883
#  G_P2NP        | 0.8999174257656039
#  G_P1NPW       | 0.6989852027273
#  G_P2NPW       | 0.698131313443825
#  G_P1BP        | 0.7543390081751994
#  G_P2BP        | 0.7533567783922449
#  G_P1BPWon     | 0.3299834469193317
#  G_P2BPWon     | 0.3286664530828078
#  G_P1FW        | 0.6808639673847436
#  G_P1BW        | 0.45968903507217057
#  G_P2FW        | 0.6787654871457572
#  G_P2BW        | 0.46109793957710393
#  G_P1SerW      | 0.19540027058960827
#  G_P2SerW      | 0.19136013110821176
#  G_avg_SerSp   | 14.309141542518406
#  G_totalPoints | 2.5883680491029444
# -RECORD 3-----------------------------
#  summary       | min
#  match_id      | 2011-ausopen-1101
#  SetNo         | 1
#  GameNo        | 1
#  SetWinP       | 1
#  G_Winner      | 0
#  G_P1GmWon     | 0
#  G_P2GmWon     | 0
#  G_Ser         | 1
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 103.33333333333333
#  G_totalPoints | 1
# -RECORD 4-----------------------------
#  summary       | max
#  match_id      | 2024-wimbledon-2701
#  SetNo         | 5
#  GameNo        | 9
#  SetWinP       | 2
#  G_Winner      | 2
#  G_P1GmWon     | 9
#  G_P2GmWon     | 9
#  G_Ser         | 2
#  G_P1Ace       | 7.0
#  G_P2Ace       | 9.0
#  G_P1Wn        | 13.0
#  G_P2Wn        | 14.0
#  G_P1Df        | 7.0
#  G_P2Df        | 7.0
#  G_P1UE        | 12.0
#  G_P2UE        | 12.0
#  G_P1NP        | 14.0
#  G_P2NP        | 12.0
#  G_P1NPW       | 7.0
#  G_P2NPW       | 8.0
#  G_P1BP        | 12.0
#  G_P2BP        | 10.0
#  G_P1BPWon     | 2.0
#  G_P2BPWon     | 2.0
#  G_P1FW        | 7
#  G_P1BW        | 5
#  G_P2FW        | 9
#  G_P2BW        | 6
#  G_P1SerW      | 5
#  G_P2SerW      | 5
#  G_avg_SerSp   | 229.25
#  G_totalPoints | 40

# %%
game_based_df.filter(F.col("G_totalPoints")==1).show(vertical=True)
# Out:
# -RECORD 0-----------------------------
#  match_id      | 2012-frenchopen-1129
#  SetNo         | 4
#  GameNo        | 3
#  SetWinP       | 1
#  G_Winner      | 1
#  G_P1GmWon     | 1
#  G_P2GmWon     | 1
#  G_Ser         | 1
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 1-----------------------------
#  match_id      | 2012-frenchopen-1129
#  SetNo         | 4
#  GameNo        | 4
#  SetWinP       | 1
#  G_Winner      | 1
#  G_P1GmWon     | 2
#  G_P2GmWon     | 1
#  G_Ser         | 2
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 1.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 2-----------------------------
#  match_id      | 2015-frenchopen-1101
#  SetNo         | 2
#  GameNo        | 10
#  SetWinP       | 1
#  G_Winner      | 0
#  G_P1GmWon     | 4
#  G_P2GmWon     | 5
#  G_Ser         | 2
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 1.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 1
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 138.0
#  G_totalPoints | 1
# -RECORD 3-----------------------------
#  match_id      | 2013-frenchopen-1402
#  SetNo         | 2
#  GameNo        | 7
#  SetWinP       | 1
#  G_Winner      | 1
#  G_P1GmWon     | 6
#  G_P2GmWon     | 1
#  G_Ser         | 1
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 1.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 1.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 1.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 178.0
#  G_totalPoints | 1
# -RECORD 4-----------------------------
#  match_id      | 2012-frenchopen-1104
#  SetNo         | 5
#  GameNo        | 8
#  SetWinP       | 1
#  G_Winner      | 2
#  G_P1GmWon     | 5
#  G_P2GmWon     | 3
#  G_Ser         | 1
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 5-----------------------------
#  match_id      | 2012-frenchopen-1129
#  SetNo         | 3
#  GameNo        | 1
#  SetWinP       | 2
#  G_Winner      | 1
#  G_P1GmWon     | 1
#  G_P2GmWon     | 0
#  G_Ser         | 2
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 6-----------------------------
#  match_id      | 2018-usopen-2701
#  SetNo         | 2
#  GameNo        | 8
#  SetWinP       | 2
#  G_Winner      | 0
#  G_P1GmWon     | 3
#  G_P2GmWon     | 4
#  G_Ser         | 2
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 7-----------------------------
#  match_id      | 2023-usopen-1105
#  SetNo         | 4
#  GameNo        | 7
#  SetWinP       | 2
#  G_Winner      | 0
#  G_P1GmWon     | 3
#  G_P2GmWon     | 3
#  G_Ser         | 1
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 0.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 0.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 0.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 162.59730345536104
#  G_totalPoints | 1
# -RECORD 8-----------------------------
#  match_id      | 2016-frenchopen-1138
#  SetNo         | 2
#  GameNo        | 10
#  SetWinP       | 2
#  G_Winner      | 2
#  G_P1GmWon     | 4
#  G_P2GmWon     | 6
#  G_Ser         | 2
#  G_P1Ace       | 0.0
#  G_P2Ace       | 0.0
#  G_P1Wn        | 0.0
#  G_P2Wn        | 0.0
#  G_P1Df        | 0.0
#  G_P2Df        | 0.0
#  G_P1UE        | 1.0
#  G_P2UE        | 0.0
#  G_P1NP        | 0.0
#  G_P2NP        | 0.0
#  G_P1NPW       | 0.0
#  G_P2NPW       | 0.0
#  G_P1BP        | 0.0
#  G_P2BP        | 1.0
#  G_P1BPWon     | 0.0
#  G_P2BPWon     | 1.0
#  G_P1FW        | 0
#  G_P1BW        | 0
#  G_P2FW        | 0
#  G_P2BW        | 0
#  G_P1SerW      | 0
#  G_P2SerW      | 0
#  G_avg_SerSp   | 170.0
#  G_totalPoints | 1

# %%
# 将所有列（除了 match_id 和 G_avg_SerSp）转换为 int 类型
columns_to_cast = [col for col in game_based_df.columns if col not in ["match_id", "G_avg_SerSp"]]
# 使用 select 和 cast 逐列转换
game_based_df = game_based_df.select(
    [col if col in ["match_id", "G_avg_SerSp"] else F.col(col).cast(IntegerType()).alias(col) for col in game_based_df.columns]
)

# %%
game_based_df.printSchema()
# Out:
# root
#  |-- match_id: string (nullable = true)
#  |-- SetNo: integer (nullable = true)
#  |-- GameNo: integer (nullable = true)
#  |-- SetWinP: integer (nullable = true)
#  |-- G_Winner: integer (nullable = true)
#  |-- G_P1GmWon: integer (nullable = true)
#  |-- G_P2GmWon: integer (nullable = true)
#  |-- G_Ser: integer (nullable = true)
#  |-- G_P1Ace: integer (nullable = true)
#  |-- G_P2Ace: integer (nullable = true)
#  |-- G_P1Wn: integer (nullable = true)
#  |-- G_P2Wn: integer (nullable = true)
#  |-- G_P1Df: integer (nullable = true)
#  |-- G_P2Df: integer (nullable = true)
#  |-- G_P1UE: integer (nullable = true)
#  |-- G_P2UE: integer (nullable = true)
#  |-- G_P1NP: integer (nullable = true)
#  |-- G_P2NP: integer (nullable = true)
#  |-- G_P1NPW: integer (nullable = true)
#  |-- G_P2NPW: integer (nullable = true)
#  |-- G_P1BP: integer (nullable = true)
#  |-- G_P2BP: integer (nullable = true)
#  |-- G_P1BPWon: integer (nullable = true)
#  |-- G_P2BPWon: integer (nullable = true)
#  |-- G_P1FW: integer (nullable = true)
#  |-- G_P1BW: integer (nullable = true)
#  |-- G_P2FW: integer (nullable = true)
#  |-- G_P2BW: integer (nullable = true)
#  |-- G_P1SerW: integer (nullable = true)
#  |-- G_P2SerW: integer (nullable = true)
#  |-- G_avg_SerSp: double (nullable = true)
#  |-- G_totalPoints: integer (nullable = false)

# %%
game_based_df.write.csv("./game_based_df.csv",header=True)

# %%
spark.stop()

# %% [markdown]
# #### 基于盘数分析

# %%
# 定义窗口，按照 match_id 和 SetNo 排序，并调整窗口范围
window_spec = Window.partitionBy("match_id", "SetNo").orderBy("PointNumber").rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing)

# 计算每个分区（match_id 和 SetNo）中的最大 SetWinner 值
df_with_max_setwinner = filtered_df.withColumn(
    "SetWinner_Max", F.max("SetWinner").over(window_spec)
)

# 显示 SetWinner_Max 为 0 的行
df_with_max_setwinner.filter(F.col("SetWinner_Max") == 0).show(n=60, vertical=True)

# 查看特定条件下的数据
#df_with_max_setwinner.filter((F.col("match_id") == "2011-ausopen-1101") & (F.col("PointNumber") == 28)).show(vertical=True)

# %%
filtered_df.show(vertical=True)

# %%
# 定义窗口，按照 match_id 和 SetNo 排序
window_spec1 = Window.partitionBy("match_id").orderBy("SetNo").rowsBetween(Window.unboundedPreceding, Window.currentRow)

# 创建 P1SetWon 和 P2SetWon 列，基于 SetWinner 列
df_with_sets = df_with_max_setwinner.withColumn(
    "P1SetWon", F.when(F.col("SetWinner") == 1, 1).otherwise(0)
).withColumn(
    "P2SetWon", F.when(F.col("SetWinner") == 2, 1).otherwise(0)
)

# 计算 P1SetWonAcc 和 P2SetWonAcc，确保累加从 0 开始
df_with_sets = df_with_sets.withColumn(
    "P1SetWonAcc", F.sum("P1SetWon").over(window_spec1)
).withColumn(
    "P2SetWonAcc", F.sum("P2SetWon").over(window_spec1)
)

# 添加新列 WP，当 P1SetWonAcc 或 P2SetWonAcc 累加到 3 后，设置 WP 为 0 或 1
df_with_sets = df_with_sets.withColumn(
    "WP", 
    F.when(F.col("P1SetWonAcc") >= 3, 1)
    .when(F.col("P2SetWonAcc") >= 3, 0)
    .otherwise(None)  # 保持为 None 直到累加到 3
)

# 使用窗口函数，填充 WP 值，在同一 match_id 分区内填充 WP 值
df_with_wp = df_with_sets.withColumn(
    "WP", F.first("WP", True).over(Window.partitionBy("match_id"))
)

# 显示结果
df_with_wp.show(vertical=True)

# %%
df_with_wp.filter(df_with_wp["WP"].isNotNull()).count()#null 609696  notnull 931846

# %%
set_based_df = (filtered_df.groupBy(
    "match_id", "SetNo"
).agg(
    F.max("P1SetWon").alias("S_P1SW"),
    F.max("P2SetWon").alias("S_P2SW"),
    F.max("P2GamesWon").alias("S_P2GmWon"),
    F.max("ServeIndicator").alias("S_Ser"),
    F.sum("P1Ace").alias("S_P1Ace"),
    F.sum("P2Ace").alias("S_P2Ace"),
    F.sum("P1Winner").alias("S_P1Wn"),
    F.sum("P2Winner").alias("S_P2Wn"),
    F.sum("P1DoubleFault").alias("S_P1Df"),
    F.sum("P2DoubleFault").alias("S_P2Df"),
    F.sum("P1UnfErr").alias("S_P1UE"),
    F.sum("P2UnfErr").alias("S_P2UE"),
    F.sum("P1NetPoint").alias("S_P1NP"),
    F.sum("P2NetPoint").alias("S_P2NP"),
    F.sum("P1NetPointWon").alias("S_P1NPW"),
    F.sum("P2NetPointWon").alias("S_P2NPW"),
    F.sum("P1BreakPoint").alias("S_P1BP"),
    F.sum("P2BreakPoint").alias("S_P2BP"),
    F.sum("P1BreakPointWon").alias("S_P1BPWon"),
    F.sum("P2BreakPointWon").alias("S_P2BPWon"),
    F.sum("P1FWinner").alias("S_P1FW"),
    F.sum("P1BWinner").alias("S_P1BW"),
    F.sum("P2FWinner").alias("S_P2FW"),
    F.sum("P2BWinner").alias("S_P2BW"),
    F.sum("P1SerWin").alias("S_P1SerW"),
    F.sum("P2SerWin").alias("S_P2SerW"),
    F.avg("Speed_KMH").alias("S_avg_SerSp"),  
    F.count("*").alias("S_totalPoints")  
))
